# %%
# %sql
Use case

1. sales data, logistic 

70-80% tables,excel ---- Genie
20-30% pdf ----- RAG (Your own, KA agent (agent bricks))

Front End APP

# %%
2. master data ( customer data, )  structured data 
anamolies ---- 

1.genie (agent) 
2. DIY using claude( .claude) databricks sdk, langchain, langgraph

# %%
custom LLM's

Agent bricks

# %%
Real time Ingestion sensors data
