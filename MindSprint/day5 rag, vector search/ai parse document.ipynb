# %%
# %sql
SELECT
ai_parse_document(
  content,
  map('version', '2.0')
) AS parsed
FROM READ_FILES('', format => 'binaryFile');

# %%
# %sql
SELECT
  path,
  ai_parse_document(content)
FROM READ_FILES('/Volumes/dev_agents/naval/raw/pdf/', format => 'binaryFile');

# %%
# %sql
SELECT
  path,
  ai_parse_document(content)
FROM READ_FILES('/Volumes/dev_agents/naval/raw/Gemini_Generated_Image_uxnw0uuxnw0uuxnw.png', format => 'binaryFile');
